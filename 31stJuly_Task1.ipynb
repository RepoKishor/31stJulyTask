# %%
import pandas as pd

# %%
#1. Read this dataset in pandas
df = pd.read_csv('FitBit data.csv')

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391   04-08-2016       23014      20.389999        20.389999
# 453  8877689391   04-09-2016       16470       8.070000         8.070000
# 454  8877689391   04-10-2016       28497      27.530001        27.530001
# 455  8877689391   04-11-2016       10622       8.060000         8.060000
# 456  8877689391   04-12-2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
missing_data=df.isnull()

# %%
df.dtypes
# Out:
# Id                            int64
# ActivityDate                 object
# TotalSteps                    int64
# TotalDistance               float64
# TrackerDistance             float64
# LoggedActivitiesDistance    float64
# VeryActiveDistance          float64
# ModeratelyActiveDistance    float64
# LightActiveDistance         float64
# SedentaryActiveDistance     float64
# VeryActiveMinutes             int64
# FairlyActiveMinutes           int64
# LightlyActiveMinutes          int64
# SedentaryMinutes              int64
# Calories                      int64
# dtype: object

# %%
#3 convert all the dates avaible in dataset to timestamp format in pandas
df['VeryActiveMinutes'] = df['VeryActiveMinutes'].apply(lambda t: pd.Timestamp(t))
df['FairlyActiveMinutes'] = df['FairlyActiveMinutes'].apply(lambda t: pd.Timestamp(t))
df['LightlyActiveMinutes'] = df['LightlyActiveMinutes'].apply(lambda t: pd.Timestamp(t))
df['SedentaryMinutes'] = df['SedentaryMinutes'].apply(lambda t: pd.Timestamp(t))

# %%
#4 . Find out in this data that how many unique id's we have
df['Agent Name'].unique()

# %%
df['Id'].unique()
# Out:
# array([1503960366, 1624580081, 1644430081, 1844505072, 1927972279,
#        2022484408, 2026352035, 2320127002, 2347167796, 2873212765,
#        2891001357, 3372868164, 3977333714, 4020332650, 4057192912,
#        4319703577, 4388161847, 4445114986, 4558609924, 4702921684,
#        5553957443, 5577150313, 6117666160, 6290855005, 6391747486,
#        6775888955, 6962181067, 7007744171, 7086361926, 8053475328,
#        8253242879, 8378563200, 8583815059, 8792009665, 8877689391],
#       dtype=int64)

# %%
df['Id'].unique().size
# Out:
# 35

# %%
#5 . which id is one of the active id that you have in whole dataset
#df[df['VeryActiveDistance'] == max(df['profit'])]['customer_name']
df.groupby('Id')['VeryActiveDistance'].sum()
# Out:
# Id
# 1503960366    52.890000
# 1624580081     0.980000
# 1644430081    11.340000
# 1844505072     0.610000
# 1927972279     0.000000
# 2022484408    37.030000
# 2026352035     0.000000
# 2320127002     0.950000
# 2347167796    12.920000
# 2873212765     3.960000
# 2891001357     0.000000
# 3372868164     7.440000
# 3977333714    10.020000
# 4020332650     5.300000
# 4057192912     3.200000
# 4319703577     5.540000
# 4388161847     0.000000
# 4445114986     6.350000
# 4558609924     2.170000
# 4702921684     3.570000
# 5553957443    18.140000
# 5577150313    34.260000
# 6117666160     0.420000
# 6290855005     2.020000
# 6391747486     2.030000
# 6775888955     8.480000
# 6962181067    36.130000
# 7007744171    42.479999
# 7086361926    18.350000
# 8053475328    93.930000
# 8253242879     7.240000
# 8378563200    23.580000
# 8583815059     0.370000
# 8792009665     0.580000
# 8877689391    87.390000
# Name: VeryActiveDistance, dtype: float64

# %%
8053475328    93.930000

# %%
#6 . how many of them have not logged there activity find out in terms of number of ids 
df.groupby('Id')['LoggedActivitiesDistance'].count()
# Out:
# Id
# 1503960366    19
# 1624580081    19
# 1644430081    10
# 1844505072    12
# 1927972279    12
# 2022484408    12
# 2026352035    12
# 2320127002    12
# 2347167796    15
# 2873212765    12
# 2891001357     8
# 3372868164    10
# 3977333714    12
# 4020332650    32
# 4057192912    32
# 4319703577    12
# 4388161847     8
# 4445114986    15
# 4558609924    12
# 4702921684    15
# 5553957443    12
# 5577150313    11
# 6117666160    10
# 6290855005    10
# 6391747486     9
# 6775888955     9
# 6962181067    14
# 7007744171    12
# 7086361926    12
# 8053475328    11
# 8253242879    12
# 8378563200    12
# 8583815059     8
# 8792009665    12
# 8877689391    12
# Name: LoggedActivitiesDistance, dtype: int64

# %%
#7 . Find out who is the laziest person id that we have in dataset 
steps_sum = df.groupby('Id')['Id', 'TotalSteps'].sum()
steps_sum['rank'] = steps_sum['TotalSteps'].rank(ascending=True)
steps_sum
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14696\1072363498.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   steps_sum = df.groupby('Id')['Id', 'TotalSteps'].sum()
#                       Id  TotalSteps  rank
# Id
# 1503960366   28575246954      221170  35.0
# 1624580081   30867021539       80299  19.0
# 1644430081   16444300810       92748  21.0
# 1844505072   22134060864       43687  11.0
# 1927972279   23135667348       26170   6.0
# 2022484408   24269812896      146099  28.0
# 2026352035   24316224420       40713  10.0
# 2320127002   27841524024       37661   9.0
# 2347167796   35207516940      147001  29.0
# 2873212765   34478553180       79639  18.0
# 2891001357   23128010856        6189   2.0
# 3372868164   33728681640       61275  14.0
# 3977333714   47728004568      103967  26.0
# 4020332650  128650644800      184851  33.0
# 4057192912  129830173184       60391  13.0
# ...

# %%
#8 . Explore over an internet that how much calories burn is required for a healthy person and find out how many healthy person we have in our dataset 
def findHealthy(a):
    if a<2600:
        return 'Not healthy'
    else:
        return "Healthy"

# %%
df['healthy_flag']= df['Calories'].apply(findHealthy)

# %%
df.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance             VeryActiveMinutes  \
# ...

# %%
df[df['healthy_flag']=='Healthy']['Id'].count()
# Out:
# 121

# %%
#10 . who is the third most active person in this dataset find out those in pandas
steps_sum = df.groupby('Id')['Id', 'TotalSteps'].sum()
steps_sum['rank'] = steps_sum['TotalSteps'].rank(ascending=True)
steps_sum
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14696\2436852579.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   steps_sum = df.groupby('Id')['Id', 'TotalSteps'].sum()
#                       Id  TotalSteps  rank
# Id
# 1503960366   28575246954      221170  35.0
# 1624580081   30867021539       80299  19.0
# 1644430081   16444300810       92748  21.0
# 1844505072   22134060864       43687  11.0
# 1927972279   23135667348       26170   6.0
# 2022484408   24269812896      146099  28.0
# 2026352035   24316224420       40713  10.0
# 2320127002   27841524024       37661   9.0
# 2347167796   35207516940      147001  29.0
# 2873212765   34478553180       79639  18.0
# 2891001357   23128010856        6189   2.0
# 3372868164   33728681640       61275  14.0
# 3977333714   47728004568      103967  26.0
# 4020332650  128650644800      184851  33.0
# 4057192912  129830173184       60391  13.0
# ...

# %%
# Rank 33 is the thrid most active with Id 4020332650 Rank - 33.0

# %%
# 11 . who is the 5th most laziest person avilable in dataset find it out

# %%
From the output of Q7,  it is Id 8583815059 Rank- 5.0

# %%
#12 . what is the total acumulative calories burn for a person find out

# %%
df.groupby('Id')['Calories'].sum()
# Out:
# Id
# 1503960366    34128
# 1624580081    25705
# 1644430081    29164
# 1844505072    19391
# 1927972279    27048
# 2022484408    29704
# 2026352035    16266
# 2320127002    18385
# 2347167796    30320
# 2873212765    20349
# 2891001357    18187
# 3372868164    18603
# 3977333714    16777
# 4020332650    98412
# 4057192912    60913
# 4319703577    23931
# 4388161847    14442
# 4445114986    31617
# 4558609924    21962
# 4702921684    42322
# 5553957443    21630
# 5577150313    36303
# 6117666160    20993
# 6290855005    21656
# 6391747486    15868
# 6775888955    24523
# 6962181067    29249
# 7007744171    31525
# 7086361926    26124
# 8053475328    31825
# 8253242879    17556
# 8378563200    40274
# 8583815059    19130
# 8792009665    24884
# 8877689391    41414
# Name: Calories, dtype: int64
